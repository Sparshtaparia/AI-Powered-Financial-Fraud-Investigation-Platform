# %% [markdown]
# # AegisAML: 02 - Model Training
#
# This notebook trains Isolation Forest, XGBoost, and Autoencoders for anomaly detection.

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest
from sklearn.metrics import classification_report, roc_auc_score, precision_recall_curve
import xgboost as xgb
import logging

# %%
def train_isolation_forest(X: pd.DataFrame, contamination: float = 0.05) -> IsolationForest:
    """Trains an Isolation Forest model."""
    print(f"Training Isolation Forest with contamination {contamination}...")
    model = IsolationForest(n_estimators=100, contamination=contamination, random_state=42)
    model.fit(X)
    return model
